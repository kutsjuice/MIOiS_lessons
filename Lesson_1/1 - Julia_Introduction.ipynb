# %% [markdown]
# # Вывод на печать

# %% [markdown]
# Для вывода на печать имеются две функции
# ```println()``` и ```print()```.

# %%
println("Привет, Мир!");
println("Привет, Мир!");

# %%
print("Привет, Мир!");
print("Привет, Мир!");

# %% [markdown]
# Перенос строки можно сделать и вручную, путем добавления символа переноса каретки ```\n```

# %%
print("Привет, Мир!\n");
print("Привет, Мир!");

# %% [markdown]
# # Объявление переменных

# %% [markdown]
# В **Julia** применяется динамическая типизация, поэтому нет необходимости объявлять типы переменных. Все что нужно - дать переменной имя и присвоить значение при помощи операции присваивания (знак ```=```)

# %%
answer_on_THE_question = 42;
typeof(answer_on_THE_question)

# %% [markdown]
# В **Julia** встроена поддержка Unicode, поэтому можно использовать символы не только на латинице

# %%
число_пи = 3.14159265;
typeof(число_пи)

# %%
Այբուբենը = "Алфавит"

# %% [markdown]
# И даже больше - в Unicode определены не только символы Алфавита

# %%
😸 = "Кот Фёдор";
typeof(😸)

# %% [markdown]
# В ```Julia``` доступна автозамена по клавише ```<tab>```. Для этого необходимо ввести название Unicode символа и нажать ```<tab>```.
# Также работает режим подсказки - необходимо начать вводить название переменной, после чего нажать ```<tab>``` и появится список переменных.
# Подсказка работает и со смайликами: достаточно начать вводить ```\:smi``` и нажать ```<tab>``` и появится список с доступными символами-смайликами.

# %% [markdown]
#  После объявления переменной мы можем переопределить переменную с другим типом

# %%
😸 = 1;
typeof(😸)

# %% [markdown]
# **Julia** позволяет писать супер-интуитивно-понятный код, примером чего является 😸. Это позволяет писать код вроде такого:

# %%
😞 = -1;

# %%
😄 = 0;

# %%
😞 + 😸 == 😄

# %% [markdown]
# # Комментирование кода

# %%
# это однострочный комментарий

# %%
#=

Это многострочный
комментарий

=#

# %% [markdown]
# # Базовые математические операции

# %%
sum = 3 + 7

# %%
dif = 3 - 7

# %%
mul = 20 * 2

# %%
div = 9/3

# %%
pow = -2^7

# %%
mod = 17 % 5

# %% [markdown]
# # Преобразование типов

# %%
a = 3.0
b = Integer(a)
typeof(b)

# %%
b = convert(Integer, a)
typeof(b)

# %%
three = "3"
convert(Int64, three)

# %%
parse(Int64, three)

# %% [markdown]
# # Справка

# %% [markdown]
# В **Julia** справка к функциям и модулям доступна при помощи ```?```

# %%
? /

# %% [markdown]
# # Упражнение 1.
# Объявите переменную ```days``` и присвойте ей значение 365. Конвертируйте значение ```days``` в тип с плавающей точкой и присвойте его значение переменной ```days_float```

# %%
@assert days == 365
@assert days_float == 365.0

# %% [markdown]
# # Упражнение 2.
# Определите $cos$ угла $\alpha = 30 ^\circ$  и сохраните результат в переменную.
